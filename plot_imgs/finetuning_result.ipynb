# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data for the four FJSP problems and four models
data = {
    '10x5 MK': [
        np.array([444.4, 444.4, 444.4, 444.4, 444.4]),
        [601.0, 430.0, 468.0, 438.0, 416.0],
        [778.0, 471.0, 492.0, 527.0, 456.0],
        [601.0, 622.0, 616.0, 609.0, 661.0]
    ],
    '20x5 MK': [
        np.array([730.7, 730.7, 730.7, 730.7, 730.7]),
        [1151.0, 727.0, 724.0, 743.0, 767.0],
        [1225.0, 910.0, 960.0, 923.0, 946.0],
        [1151.0, 1115.0, 1231.0, 1089.0, 1170.0]
    ],
    '15x10 MK': [
        np.array([598.4, 598.4, 598.4, 598.4, 598.4]),
        [969.0, 703.0, 643.0, 654.0, 613.0],
        [1290.0, 715.0, 719.0, 765.0, 652.0],
        [969.0, 991.0, 810.0, 809.0, 780.0]
    ],
    '20x10 MK': [
        np.array([659.0, 659.0, 659.0, 659.0, 659.0]),
        [1260.0, 784.0, 771.0, 777.0, 752.0],
        [1556.0, 933.0, 1039.0, 1091.0, 990.0],
        [1260.0, 1107.0, 1108.0, 1106.0, 1078.0]
    ]
}

# Model names
model_names = ["DAN_baseline", "MAML", "pre_training", "random"]

# Setup the figure and axes
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Epochs for the x-axis
epochs = [1, 2, 3, 4, 5]

# Iterate through each FJSP problem and plot the data
for idx, (problem, results) in enumerate(data.items()):
    letter = chr(ord('a') + idx)
    for i, result in enumerate(results):
        axes[idx].plot(epochs, result, label=model_names[i], linewidth=0.8, marker='o', markersize=4)
    axes[idx].set_xlabel('Finetuning Epoch', fontsize=14)  # X-axis label font size
    axes[idx].set_ylabel('Makespan', fontsize=14)  # Y-axis label font size
    axes[idx].legend()

    # Set the title below each subplot using ax.text()
    axes[idx].text(0.5, -0.2, f'({letter}) {problem}', ha='center', va='center', fontsize=20, transform=axes[idx].transAxes)

# Adjust the layout to avoid overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data for the four FJSP problems and four models
data = {
    '10x5 MK': [
        np.array([444.4, 444.4, 444.4, 444.4, 444.4]),
        [601.0, 430.0, 468.0, 438.0, 416.0],
        [778.0, 471.0, 492.0, 527.0, 456.0],
        [601.0, 622.0, 616.0, 609.0, 661.0]
    ],
    '20x5 MK': [
        np.array([730.7, 730.7, 730.7, 730.7, 730.7]),
        [1151.0, 727.0, 724.0, 743.0, 767.0],
        [1225.0, 910.0, 960.0, 923.0, 946.0],
        [1151.0, 1115.0, 1231.0, 1089.0, 1170.0]
    ],
    '15x10 MK': [
        np.array([598.4, 598.4, 598.4, 598.4, 598.4]),
        [969.0, 703.0, 643.0, 654.0, 613.0],
        [1290.0, 715.0, 719.0, 765.0, 652.0],
        [969.0, 991.0, 810.0, 809.0, 780.0]
    ],
    '20x10 MK': [
        np.array([659.0, 659.0, 659.0, 659.0, 659.0]),
        [1260.0, 784.0, 771.0, 777.0, 752.0],
        [1556.0, 933.0, 1039.0, 1091.0, 990.0],
        [1260.0, 1107.0, 1108.0, 1106.0, 1078.0]
    ]
}

# Model names and markers
model_names = ["DAN_baseline", "MAML", "pre_training", "random"]
markers = ['o', 's', 'D', '^']  # Different markers for each model
colors = ['blue', 'green', 'red', 'purple']  # Different colors for each model

# Setup the figure and axes
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Epochs for the x-axis
epochs = [1, 2, 3, 4, 5]

# Iterate through each FJSP problem and plot the data
for idx, (problem, results) in enumerate(data.items()):
    letter = chr(ord('a') + idx)
    for i, result in enumerate(results):
        axes[idx].plot(
            epochs, result, label=model_names[i], linewidth=1.0,
            marker=markers[i], markersize=6, color=colors[i]
        )
    # Set the "title" below each subplot as the x-label
    # Set the title below each subplot using ax.text()
    axes[idx].text(0.5, -0.2, f'({letter}) {problem}', ha='center', va='center', fontsize=20, transform=axes[idx].transAxes)
    axes[idx].set_xlabel('Finetuning Epoch', fontsize=14)  # X-axis label font size
    axes[idx].set_ylabel('Makespan', fontsize=12)
    axes[idx].set_xticks(epochs)  # Set x-axis step to 1
    axes[idx].legend()

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data for the four FJSP problems and four models
data = {'10x5 EC': [np.array([38.72207053, 38.72207053, 38.72207053, 38.72207053, 38.72207053]),
  [59.26793110811374,
   35.214980674907885,
   37.9251552855044,
   37.16119885920116,
   44.47080190557376],
  [57.43784050587376,
   43.71083572743409,
   42.657523904093736,
   44.45941165178706,
   43.13169369460941],
  [59.26793110811374,
   52.799513604405675,
   52.59197630918018,
   57.24299910456212,
   61.58831177157902]],
 '20x5 EC': [np.array([69.61430615, 69.61430615, 69.61430615, 69.61430615, 69.61430615]),
  [110.24074199617301,
   65.72866256817395,
   65.66751975636666,
   67.77408835801592,
   71.7380955298351],
  [115.92716990746788,
   75.5568135054829,
   74.56679392655495,
   72.12114795677566,
   72.38167984037467],
  [110.24074199617301,
   111.41584559325072,
   112.55370498683692,
   117.9788456862732,
   112.35032406004315]],
 '15x10 EC': [np.array([117.1848488, 117.1848488, 117.1848488, 117.1848488, 117.1848488]),
  [161.12782421585672,
   116.46058844757489,
   132.41028298747779,
   119.62774757464145,
   121.08524497651321],
  [156.5819021730394,
   125.91035852844306,
   119.2340079492015,
   124.79067051335429,
   126.01463311469853],
  [161.12782421585672,
   155.9261221274023,
   164.443506873557,
   166.90907885250567,
   170.36719131823477]],
 '20x10 EC': [np.array([155.97603248, 155.97603248, 155.97603248, 155.97603248,
         155.97603248]),
  [213.90746724057382,
   136.7843147790451,
   141.5397714414361,
   134.28111405730007,
   134.81643400436045],
  [217.6184552943394,
   149.30409657925702,
   148.5813719334982,
   155.7058117969605,
   147.63847099175632],
  [213.90746724057382,
   215.57853322972056,
   212.59432625061243,
   211.69586207078086,
   211.36706204573665]]}

# Model names and markers
model_names = ["DAN_baseline", "MAML", "pre_training", "random"]
markers = ['o', 's', 'D', '^']  # Different markers for each model
colors = ['blue', 'green', 'red', 'purple']  # Different colors for each model

# Setup the figure and axes
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Epochs for the x-axis
epochs = [1, 2, 3, 4, 5]

# Iterate through each FJSP problem and plot the data
for idx, (problem, results) in enumerate(data.items()):
    letter = chr(ord('a') + idx)
    for i, result in enumerate(results):
        axes[idx].plot(
            epochs, result, label=model_names[i], linewidth=1.0,
            marker=markers[i], markersize=6, color=colors[i]
        )
    # Set the "title" below each subplot as the x-label
    axes[idx].text(0.5, -0.2, f'({letter}) {problem}', ha='center', va='center', fontsize=20, transform=axes[idx].transAxes)
    axes[idx].set_xlabel('Finetuning Epoch', fontsize=14)  # X-axis label font size
    axes[idx].set_ylabel('Energy Consumption', fontsize=12)
    axes[idx].set_xticks(epochs)  # Set x-axis step to 1
    axes[idx].legend()

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data for the four FJSP problems and four models
data = {'10x5': [np.array([38.72207053, 38.72207053, 38.72207053, 38.72207053, 38.72207053]),
  [59.26793110811374,
   35.214980674907885,
   37.9251552855044,
   37.16119885920116,
   44.47080190557376],
  [57.43784050587376,
   43.71083572743409,
   42.657523904093736,
   44.45941165178706,
   43.13169369460941],
  [59.26793110811374,
   52.799513604405675,
   52.59197630918018,
   57.24299910456212,
   61.58831177157902]],
 '20x5': [np.array([69.61430615, 69.61430615, 69.61430615, 69.61430615, 69.61430615]),
  [110.24074199617301,
   65.72866256817395,
   65.66751975636666,
   67.77408835801592,
   71.7380955298351],
  [115.92716990746788,
   75.5568135054829,
   74.56679392655495,
   72.12114795677566,
   72.38167984037467],
  [110.24074199617301,
   111.41584559325072,
   112.55370498683692,
   117.9788456862732,
   112.35032406004315]],
 '15x10': [np.array([117.1848488, 117.1848488, 117.1848488, 117.1848488, 117.1848488]),
  [161.12782421585672,
   116.46058844757489,
   132.41028298747779,
   119.62774757464145,
   121.08524497651321],
  [156.5819021730394,
   125.91035852844306,
   119.2340079492015,
   124.79067051335429,
   126.01463311469853],
  [161.12782421585672,
   155.9261221274023,
   164.443506873557,
   166.90907885250567,
   170.36719131823477]],
 '20x10': [np.array([155.97603248, 155.97603248, 155.97603248, 155.97603248,
         155.97603248]),
  [213.90746724057382,
   136.7843147790451,
   141.5397714414361,
   134.28111405730007,
   134.81643400436045],
  [217.6184552943394,
   149.30409657925702,
   148.5813719334982,
   155.7058117969605,
   147.63847099175632],
  [213.90746724057382,
   215.57853322972056,
   212.59432625061243,
   211.69586207078086,
   211.36706204573665]]}


# Model names and markers
model_names = ["DAN_baseline", "MAML", "pre_training", "random"]
markers = ['o', 's', 'D', '^']  # Different markers for each model
colors = ['blue', 'green', 'red', 'purple']  # Different colors for each model

# Setup the figure and axes
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Epochs for the x-axis
epochs = [1, 2, 3, 4, 5]

# Iterate through each FJSP problem and plot the data
for idx, (problem, results) in enumerate(data.items()):
    letter = chr(ord('a') + idx)
    for i, result in enumerate(results):
        axes[idx].plot(
            epochs, result, label=model_names[i], linewidth=1.0,
            marker=markers[i], markersize=6, color=colors[i]
        )
    # Set the "title" below each subplot as the x-label
    axes[idx].set_xlabel(f'({letter}) {problem}', fontsize=18)  # Simulate title below plot
    axes[idx].set_ylabel('Makespan', fontsize=12)
    axes[idx].set_xticks(epochs)  # Set x-axis step to 1
    axes[idx].legend()

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data for the four FJSP problems and four models
data = {'10x5 ECMK': [np.array([-4.81438487, -4.81438487, -4.81438487, -4.81438487, -4.81438487]), 
[-6.934126430710807, -4.921160061994528, -4.861220781521545, -4.873497949771568, -4.805513751081617], 
[-6.934126430710807, -5.10744322873755, -5.616140700798299, -5.309308675776508, -5.488833766000879], 
[-6.934126430710807, -6.788258416529996, -7.010651951853144, -6.868175322232039, -6.59947250784217]], 
'20x5 ECMK': [np.array([-7.75463034, -7.75463034, -7.75463034, -7.75463034, -7.75463034]), 
                [-12.696068544655637, -7.5553591518222465, -7.6102191730659765, -7.580408239649744, -7.501066194868249], 
                [-12.696068544655637, -9.870667054018908, -10.356105301724336, -9.877472499609379, -9.943486698494933], 
                [-12.696068544655637, -12.14421089368023, -12.624118873132463, -12.52273172816164, -12.880945141821252]], 
'15x10 ECMK': [np.array([-8.78209681, -8.78209681, -8.78209681, -8.78209681, -8.78209681]), 
                 [-13.89444169121983, -9.100869346927318, -9.334189557340949, -8.912196530877713, -9.215201259680061], 
                 [-13.89444169121983, -11.79388625669323, -11.677382274114187, -11.151564361445349, -10.920303896880261], 
                 [-13.89444169121983, -13.3856757146638, -13.152947645921142, -13.5064665400777, -13.678472015820905]], 
'20x10 ECMK': [np.array([-8.77207095, -8.77207095, -8.77207095, -8.77207095, -8.77207095]), 
                   [-18.066080879568897, -9.16269082706809, -8.917548602646635, -8.896978898583637, -8.791094788587364], 
                 [-18.066080879568897, -15.77129870940891, -15.86082493918856, -15.106162395715344, -15.158389221527665],
                   [-18.066080879568897, -17.59773936449146, -17.681123855237256, -17.40598288696681, -17.11584365682892]]}


# Model names and markers
model_names = ["DAN_baseline", "MAML", "pre_training", "random"]
markers = ['o', 's', 'D', '^']  # Different markers for each model
colors = ['blue', 'green', 'red', 'purple']  # Different colors for each model

# Setup the figure and axes
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Epochs for the x-axis
epochs = [1, 2, 3, 4, 5]

# Iterate through each FJSP problem and plot the data
for idx, (problem, results) in enumerate(data.items()):
    letter = chr(ord('a') + idx)
    for i, result in enumerate(results):
        axes[idx].plot(
            epochs, result, label=model_names[i], linewidth=1.0,
            marker=markers[i], markersize=6, color=colors[i]
        )
    # Set the "title" below each subplot as the x-label
    axes[idx].text(0.5, -0.2, f'({letter}) {problem}', ha='center', va='center', fontsize=20, transform=axes[idx].transAxes)
    axes[idx].set_xlabel('Finetuning Epoch', fontsize=14)  # X-axis label font size
    axes[idx].set_ylabel('Total Reward', fontsize=12)
    axes[idx].set_xticks(epochs)  # Set x-axis step to 1
    axes[idx].legend()

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
baseline = {
    '10x5 MK': [444.4, 444.4, 444.4, 444.4, 444.4],
    '20x5 MK': [730.7, 730.7, 730.7, 730.7, 730.7],
    '15x10 MK':[598.4, 598.4, 598.4, 598.4, 598.4],
    '20x10 MK': [659.0, 659.0, 659.0, 659.0, 659.0]
}

MAML_finetuning = {
    '10x5 MK':  [601.0, 430.0, 468.0, 438.0, 416.0],
    '20x5 MK': [1151.0, 727.0, 724.0, 743.0, 767.0],
    '15x10 MK':[969.0, 703.0, 643.0, 654.0, 613.0],
    '20x10 MK': [1260.0, 784.0, 771.0, 777.0, 752.0],
}

VAE_finetuning = {
    '10x5 MK':  [711.0, 416.0, 443.0, 431.0, 376.0],
    '20x5 MK': [1119.0, 618.0, 633.0, 649.0, 647.0],
    '15x10 MK':[963.0, 631.0, 620.0, 637.0, 600.0],
    '20x10 MK': [1112.0, 600.0, 655.0, 653.0, 627.0],
}

# 绘制每个问题的折线图
def plot_finetuning_results():
    for problem in baseline.keys():
        plt.figure(figsize=(8, 6))
        plt.plot(range(1, 6), baseline[problem], label='Baseline', marker='o', linestyle='-', color='blue')
        plt.plot(range(1, 6), MAML_finetuning[problem], label='MAML Finetuning', marker='o', linestyle='-', color='green')
        plt.plot(range(1, 6), VAE_finetuning[problem], label='VAE Finetuning', marker='o', linestyle='-', color='red')
        
        # 添加标题和标签
        plt.title(f'Finetuning Results for {problem}')
        plt.xlabel('Finetuning Step')
        plt.ylabel('Performance Metric')
        plt.xticks(range(1, 6))
        plt.legend()
        plt.grid(True)
        
        # 显示图形
        plt.tight_layout()
        plt.show()

# 调用函数绘制图表
plot_finetuning_results()

# %%
import matplotlib.pyplot as plt

# 数据
baseline = {
    '10x5 MK': [444.4, 444.4, 444.4, 444.4, 444.4],
    '20x5 MK': [730.7, 730.7, 730.7, 730.7, 730.7],
    '15x10 MK':[598.4, 598.4, 598.4, 598.4, 598.4],
    '20x10 MK': [659.0, 659.0, 659.0, 659.0, 659.0]
}

MAML_finetuning = {
    '10x5 MK':  [601.0, 430.0, 468.0, 438.0, 416.0],
    '20x5 MK': [1151.0, 727.0, 724.0, 743.0, 767.0],
    '15x10 MK':[969.0, 703.0, 643.0, 654.0, 613.0],
    '20x10 MK': [1260.0, 784.0, 771.0, 777.0, 752.0],
}

VAE_finetuning = {
    '10x5 MK':  [711.0, 416.0, 443.0, 431.0, 376.0],
    '20x5 MK': [1119.0, 618.0, 633.0, 649.0, 647.0],
    '15x10 MK':[963.0, 631.0, 620.0, 637.0, 600.0],
    '20x10 MK': [1112.0, 600.0, 655.0, 653.0, 627.0],
}

# 绘制每个问题的折线图
def plot_finetuning_results():
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))  # 创建2x2子图布局
    axes = axes.flatten()  # 将二维数组展平，方便访问

    for idx, problem in enumerate(baseline.keys()):
        ax = axes[idx]  # 获取当前子图
        ax.plot(range(1, 6), baseline[problem], label='Baseline', marker='o', linestyle='-', color='blue')
        ax.plot(range(1, 6), MAML_finetuning[problem], label='MAML Finetuning', marker='o', linestyle='-', color='green')
        ax.plot(range(1, 6), VAE_finetuning[problem], label='VAE Finetuning', marker='o', linestyle='-', color='red')
        
        # 添加标题和标签
        ax.set_title(f'Finetuning Results for {problem}')
        ax.set_xlabel('Finetuning Step')
        ax.set_ylabel('Performance Metric')
        ax.set_xticks(range(1, 6))
        ax.grid(True)
        ax.legend()

    # 调整布局
    plt.tight_layout()
    plt.show()

# 调用函数绘制图表
plot_finetuning_results()

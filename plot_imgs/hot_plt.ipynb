# %%
import matplotlib.pyplot as plt
import numpy as np

# 模拟数据：创建一个随机数据矩阵
data = np.random.rand(10, 10)

def hot_plt(data, title='Algorithm Performance Heatmap', x_label="Number of Jobs", y_label="Number of Machines"):
    labels = [5, 8, 11, 14, 17, 20, 23, 25]

    # 绘制热图
    plt.figure(figsize=(8, 6))
    heatmap = plt.imshow(data, interpolation='nearest', cmap='viridis')
    plt.colorbar(heatmap)
    # 我们假设data的尺寸与labels数组的长度匹配
    plt.xticks(range(len(labels)), labels)
    plt.yticks(range(len(labels)), labels)
    # 添加标题和轴标签
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    # 显示图表
    plt.show()

# %%
model1_list = []
with open("./model1.txt", "r") as f:
    for num in f:
        model1_list.append(float(num))

model1 = np.array(model1_list).reshape(8,8)
print(model1)

model2 = model1+100

hot_plt(model1 / model2)
# Out:
# [[ 303.3   367.9   370.4   367.1   408.1   402.5   468.4   401.  ]
#  [ 396.6   457.7   468.5   479.9   452.6   481.8   484.8   513.9 ]
#  [ 505.5   538.5   576.5   549.3   556.1   532.9   560.4   549.9 ]
#  [ 606.1   578.8   681.3   699.8   698.8   667.4   600.3   620.6 ]
#  [ 683.4   643.6   691.9   774.8   812.9   750.2   698.5   695.7 ]
#  [ 773.31  721.2   752.1   794.9   906.7   899.9   843.7   784.6 ]
#  [ 860.5   762.9   772.5   810.2   887.2  1044.   1021.2   934.6 ]
#  [ 984.8   817.2   784.2   852.8   904.    998.1  1140.   1104.3 ]]

# %%
# Out:
# 512 512
# [('./trained_network/SD2/maml+EXP19maml1709218650.pth', 'maml+EXP19maml1709218650')]
# datta[1]:  5x5+mix
# -------------------------Test Learned Model-------------------------
# test data name: 5x5+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  303.3
# time:  0.14866766929626465
# ====================================================================================================
# datta[1]:  5x8+mix
# -------------------------Test Learned Model-------------------------
# test data name: 5x8+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  367.9
# time:  0.23879597187042237
# ====================================================================================================
# datta[1]:  5x11+mix
# -------------------------Test Learned Model-------------------------
# test data name: 5x11+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  370.4
# time:  0.327200722694397
# ====================================================================================================
# datta[1]:  5x14+mix
# -------------------------Test Learned Model-------------------------
# test data name: 5x14+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  367.1
# time:  0.42349112033843994
# ====================================================================================================
# datta[1]:  5x17+mix
# -------------------------Test Learned Model-------------------------
# test data name: 5x17+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  408.1
# time:  0.5186712980270386
# ====================================================================================================
# datta[1]:  5x20+mix
# -------------------------Test Learned Model-------------------------
# test data name: 5x20+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  402.5
# time:  0.6126994609832763
# ====================================================================================================
# datta[1]:  5x23+mix
# -------------------------Test Learned Model-------------------------
# test data name: 5x23+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  468.4
# time:  0.7127901792526246
# ====================================================================================================
# datta[1]:  5x25+mix
# -------------------------Test Learned Model-------------------------
# test data name: 5x25+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  401.0
# time:  0.7891420125961304
# ====================================================================================================
# datta[1]:  8x5+mix
# -------------------------Test Learned Model-------------------------
# test data name: 8x5+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  396.6
# time:  0.2410285711288452
# ====================================================================================================
# datta[1]:  8x8+mix
# -------------------------Test Learned Model-------------------------
# test data name: 8x8+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  457.7
# time:  0.38750057220458983
# ====================================================================================================
# datta[1]:  8x11+mix
# -------------------------Test Learned Model-------------------------
# test data name: 8x11+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  468.5
# time:  0.5411306858062744
# ====================================================================================================
# datta[1]:  8x14+mix
# -------------------------Test Learned Model-------------------------
# test data name: 8x14+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  479.9
# time:  0.6908781051635742
# ====================================================================================================
# datta[1]:  8x17+mix
# -------------------------Test Learned Model-------------------------
# test data name: 8x17+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  452.6
# time:  0.8532295227050781
# ====================================================================================================
# datta[1]:  8x20+mix
# -------------------------Test Learned Model-------------------------
# test data name: 8x20+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  481.8
# time:  0.9890503883361816
# ====================================================================================================
# datta[1]:  8x23+mix
# -------------------------Test Learned Model-------------------------
# test data name: 8x23+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  484.8
# time:  1.1661015272140502
# ====================================================================================================
# datta[1]:  8x25+mix
# -------------------------Test Learned Model-------------------------
# test data name: 8x25+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  513.9
# time:  1.2761136531829833
# ====================================================================================================
# datta[1]:  11x5+mix
# -------------------------Test Learned Model-------------------------
# test data name: 11x5+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  505.5
# time:  0.3304324150085449
# ====================================================================================================
# datta[1]:  11x8+mix
# -------------------------Test Learned Model-------------------------
# test data name: 11x8+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  538.5
# time:  0.5335772275924683
# ====================================================================================================
# datta[1]:  11x11+mix
# -------------------------Test Learned Model-------------------------
# test data name: 11x11+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  576.5
# time:  0.7445839405059814
# ====================================================================================================
# datta[1]:  11x14+mix
# -------------------------Test Learned Model-------------------------
# test data name: 11x14+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  549.3
# time:  0.9608571767807007
# ====================================================================================================
# datta[1]:  11x17+mix
# -------------------------Test Learned Model-------------------------
# test data name: 11x17+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  556.1
# time:  1.165253257751465
# ====================================================================================================
# datta[1]:  11x20+mix
# -------------------------Test Learned Model-------------------------
# test data name: 11x20+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  532.9
# time:  1.4017288208007812
# ====================================================================================================
# datta[1]:  11x23+mix
# -------------------------Test Learned Model-------------------------
# test data name: 11x23+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  560.4
# time:  1.6329955816268922
# ====================================================================================================
# datta[1]:  11x25+mix
# -------------------------Test Learned Model-------------------------
# test data name: 11x25+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  549.9
# time:  1.7834936857223511
# ====================================================================================================
# datta[1]:  14x5+mix
# -------------------------Test Learned Model-------------------------
# test data name: 14x5+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  606.1
# time:  0.425806450843811
# ====================================================================================================
# datta[1]:  14x8+mix
# -------------------------Test Learned Model-------------------------
# test data name: 14x8+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  578.8
# time:  0.6850083827972412
# ====================================================================================================
# datta[1]:  14x11+mix
# -------------------------Test Learned Model-------------------------
# test data name: 14x11+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  681.3
# time:  0.9514297008514404
# ====================================================================================================
# datta[1]:  14x14+mix
# -------------------------Test Learned Model-------------------------
# test data name: 14x14+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  699.8
# time:  1.2272258043289184
# ====================================================================================================
# datta[1]:  14x17+mix
# -------------------------Test Learned Model-------------------------
# test data name: 14x17+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  698.8
# time:  1.5047183513641358
# ====================================================================================================
# datta[1]:  14x20+mix
# -------------------------Test Learned Model-------------------------
# test data name: 14x20+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  667.4
# time:  1.7748919010162354
# ====================================================================================================
# datta[1]:  14x23+mix
# -------------------------Test Learned Model-------------------------
# test data name: 14x23+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  600.3
# time:  2.0817160606384277
# ====================================================================================================
# datta[1]:  14x25+mix
# -------------------------Test Learned Model-------------------------
# test data name: 14x25+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  620.6
# time:  2.2785093069076536
# ====================================================================================================
# datta[1]:  17x5+mix
# -------------------------Test Learned Model-------------------------
# test data name: 17x5+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  683.4
# time:  0.5143635272979736
# ====================================================================================================
# datta[1]:  17x8+mix
# -------------------------Test Learned Model-------------------------
# test data name: 17x8+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  643.6
# time:  0.8417987108230591
# ====================================================================================================
# datta[1]:  17x11+mix
# -------------------------Test Learned Model-------------------------
# test data name: 17x11+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  691.9
# time:  1.158560585975647
# ====================================================================================================
# datta[1]:  17x14+mix
# -------------------------Test Learned Model-------------------------
# test data name: 17x14+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  774.8
# time:  1.4804316282272338
# ====================================================================================================
# datta[1]:  17x17+mix
# -------------------------Test Learned Model-------------------------
# test data name: 17x17+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  812.9
# time:  1.819406223297119
# ====================================================================================================
# datta[1]:  17x20+mix
# -------------------------Test Learned Model-------------------------
# test data name: 17x20+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  750.2
# time:  2.1938580513000487
# ====================================================================================================
# datta[1]:  17x23+mix
# -------------------------Test Learned Model-------------------------
# test data name: 17x23+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  698.5
# time:  2.5873836278915405
# ====================================================================================================
# datta[1]:  17x25+mix
# -------------------------Test Learned Model-------------------------
# test data name: 17x25+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  695.7
# time:  2.809180569648743
# ====================================================================================================
# datta[1]:  20x5+mix
# -------------------------Test Learned Model-------------------------
# test data name: 20x5+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  799.0
# time:  0.6031763792037964
# ====================================================================================================
# datta[1]:  20x8+mix
# -------------------------Test Learned Model-------------------------
# test data name: 20x8+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  721.2
# time:  0.9752527236938476
# ====================================================================================================
# datta[1]:  20x11+mix
# -------------------------Test Learned Model-------------------------
# test data name: 20x11+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  752.1
# time:  1.364015793800354
# ====================================================================================================
# datta[1]:  20x14+mix
# -------------------------Test Learned Model-------------------------
# test data name: 20x14+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  794.9
# time:  1.7572667360305787
# ====================================================================================================
# datta[1]:  20x17+mix
# -------------------------Test Learned Model-------------------------
# test data name: 20x17+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  906.7
# time:  2.1589096069335936
# ====================================================================================================
# datta[1]:  20x20+mix
# -------------------------Test Learned Model-------------------------
# test data name: 20x20+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  899.9
# time:  2.618477630615234
# ====================================================================================================
# datta[1]:  20x23+mix
# -------------------------Test Learned Model-------------------------
# test data name: 20x23+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  843.7
# time:  3.0716943025588987
# ====================================================================================================
# datta[1]:  20x25+mix
# -------------------------Test Learned Model-------------------------
# test data name: 20x25+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  784.6
# time:  3.407090401649475
# ====================================================================================================
# datta[1]:  23x5+mix
# -------------------------Test Learned Model-------------------------
# test data name: 23x5+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  860.5
# time:  0.7020363330841064
# ====================================================================================================
# datta[1]:  23x8+mix
# -------------------------Test Learned Model-------------------------
# test data name: 23x8+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  762.9
# time:  1.130485463142395
# ====================================================================================================
# datta[1]:  23x11+mix
# -------------------------Test Learned Model-------------------------
# test data name: 23x11+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  772.5
# time:  1.5957382440567016
# ====================================================================================================
# datta[1]:  23x14+mix
# -------------------------Test Learned Model-------------------------
# test data name: 23x14+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  810.2
# time:  2.046232557296753
# ====================================================================================================
# datta[1]:  23x17+mix
# -------------------------Test Learned Model-------------------------
# test data name: 23x17+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  887.2
# time:  2.509250211715698
# ====================================================================================================
# datta[1]:  23x20+mix
# -------------------------Test Learned Model-------------------------
# test data name: 23x20+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  1044.0
# time:  3.0295499324798585
# ====================================================================================================
# datta[1]:  23x23+mix
# -------------------------Test Learned Model-------------------------
# test data name: 23x23+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  1021.2
# time:  3.5939642906188967
# ====================================================================================================
# datta[1]:  23x25+mix
# -------------------------Test Learned Model-------------------------
# test data name: 23x25+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  934.6
# time:  3.9508209228515625
# ====================================================================================================
# datta[1]:  25x5+mix
# -------------------------Test Learned Model-------------------------
# test data name: 25x5+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  984.8
# time:  0.7658033609390259
# ====================================================================================================
# datta[1]:  25x8+mix
# -------------------------Test Learned Model-------------------------
# test data name: 25x8+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  817.2
# time:  1.2430735588073731
# ====================================================================================================
# datta[1]:  25x11+mix
# -------------------------Test Learned Model-------------------------
# test data name: 25x11+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  784.2
# time:  1.7254877805709838
# ====================================================================================================
# datta[1]:  25x14+mix
# -------------------------Test Learned Model-------------------------
# test data name: 25x14+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  852.8
# time:  2.2241455078125
# ====================================================================================================
# datta[1]:  25x17+mix
# -------------------------Test Learned Model-------------------------
# test data name: 25x17+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  904.0
# time:  2.750538730621338
# ====================================================================================================
# datta[1]:  25x20+mix
# -------------------------Test Learned Model-------------------------
# test data name: 25x20+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  998.1
# time:  3.2808867931365966
# ====================================================================================================
# datta[1]:  25x23+mix
# -------------------------Test Learned Model-------------------------
# test data name: 25x23+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  1140.0
# time:  3.916924786567688
# ====================================================================================================
# datta[1]:  25x25+mix
# -------------------------Test Learned Model-------------------------
# test data name: 25x25+mix
# Model name : maml+EXP19maml1709218650
# testing results:
# makespan(greedy):  1104.3
# time:  4.349817204475403
# ====================================================================================================
# 64 64
# [('./trained_network/SD2/test_random.pth', 'test_random')]
# datta[1]:  5x5+mix
# -------------------------Test Learned Model-------------------------
# test data name: 5x5+mix
# Model name : test_random
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 MAML_finetuning("maml+EXP19maml1709218650", "test_random")
#
# Cell In[5], line 62, in MAML_finetuning(model1, model2)
#      59 args2 = ["--test_data", *test_data,
#      60      "--test_model", model2]
#      61 model1_res, _ = MAML_finetuning_test(args = args1)
# ---> 62 model2_res, _ = MAML_finetuning_test(args = args2)
#      64 print(model1_res.shape, model2_res.shape)
#
# Cell In[5], line 24, in MAML_finetuning_test(args)
#      22 print(f"Model name : {model[1]}")
#      23 result_5_times = []
# ---> 24 test = Test(configs, data[0], model[0])
#      25 result = test.finetuning(times=4)
#      26 finetuning_makespans.append(result)
#
# File ~/FJSP-DRL-MAML/test_script/base.py:31, in Test.__init__(self, config, data_set, model_path)
#      29 setup_seed(config.seed_test)
#      30 self.ppo=PPO_initialize(config)
# ---> 31 self.ppo.policy.load_state_dict(torch.load(model_path, map_location='cuda'))
#      32 n_j = data_set[0][0].shape[0]
#      33 n_op, n_m = data_set[1][0].shape
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:2041, in Module.load_state_dict(self, state_dict, strict)
#    2036         error_msgs.insert(
#    2037             0, 'Missing key(s) in state_dict: {}. '.format(
#    2038                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    2040 if len(error_msgs) > 0:
# -> 2041     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2042                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2043 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for DANIEL:
# 	size mismatch for feature_exact.op_attention_blocks.0.attention_0.W: copying a param with shape torch.Size([12, 32]) from checkpoint, the shape in current model is torch.Size([10, 32]).
# 	size mismatch for feature_exact.op_attention_blocks.0.attention_1.W: copying a param with shape torch.Size([12, 32]) from checkpoint, the shape in current model is torch.Size([10, 32]).
# 	size mismatch for feature_exact.op_attention_blocks.0.attention_2.W: copying a param with shape torch.Size([12, 32]) from checkpoint, the shape in current model is torch.Size([10, 32]).
# 	size mismatch for feature_exact.op_attention_blocks.0.attention_3.W: copying a param with shape torch.Size([12, 32]) from checkpoint, the shape in current model is torch.Size([10, 32]).
# 	size mismatch for feature_exact.mch_attention_blocks.0.attention_0.W: copying a param with shape torch.Size([9, 32]) from checkpoint, the shape in current model is torch.Size([8, 32]).
# 	size mismatch for feature_exact.mch_attention_blocks.0.attention_0.W_edge: copying a param with shape torch.Size([12, 32]) from checkpoint, the shape in current model is torch.Size([10, 32]).
# 	size mismatch for feature_exact.mch_attention_blocks.0.attention_1.W: copying a param with shape torch.Size([9, 32]) from checkpoint, the shape in current model is torch.Size([8, 32]).
# 	size mismatch for feature_exact.mch_attention_blocks.0.attention_1.W_edge: copying a param with shape torch.Size([12, 32]) from checkpoint, the shape in current model is torch.Size([10, 32]).
# 	size mismatch for feature_exact.mch_attention_blocks.0.attention_2.W: copying a param with shape torch.Size([9, 32]) from checkpoint, the shape in current model is torch.Size([8, 32]).
# 	size mismatch for feature_exact.mch_attention_blocks.0.attention_2.W_edge: copying a param with shape torch.Size([12, 32]) from checkpoint, the shape in current model is torch.Size([10, 32]).
# 	size mismatch for feature_exact.mch_attention_blocks.0.attention_3.W: copying a param with shape torch.Size([9, 32]) from checkpoint, the shape in current model is torch.Size([8, 32]).
# 	size mismatch for feature_exact.mch_attention_blocks.0.attention_3.W_edge: copying a param with shape torch.Size([12, 32]) from checkpoint, the shape in current model is torch.Size([10, 32]).
